# %% [markdown]
# # Implementing market basket analysis

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.11/dist-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
myretaildata = pd.read_excel('MBA_data.xlsx')
myretaildata.head()
# Out:
#          Invoice No      Invoice Created Shipping Address State  \
# 0  I0925NC000006465  2025-01-01 10:05:00            Maharashtra
# 1  I0925NC000006475  2025-01-02 09:50:00            Maharashtra
# 2  I0925NC000006477  2025-01-02 09:50:00                Haryana
# 3  I0925NC000006476  2025-01-02 09:49:00          Uttar Pradesh
# 4  I0925NC000006480  2025-01-02 09:50:00              Karnataka
#
#                                       Item Type Name    Item SKU Code     MRP  \
# 0   Women Regular Kurta with Churidar & With Dupatta      ADKSET157-M  6499.0
# 1  Women Ethnic Motifs Panelled Sequinned Chander...     ADKSET261-XS  6299.0
# 2  Floral Embroidered Siquinned V-Neck Flared Geo...      ADDRS180-XL  4499.0
# 3           Embroidered Round Neck Top With Palazzos    ADCRDSET163-M  5499.0
# 4                  Printed Top With Trousers Co-Ords  ADCRDSET218AA-M  3999.0
#
#    Customer Id  Separator
# 0     20003549          1
# 1     20004807          1
# 2     20004884          1
# 3     20005795          1
# 4     20006378          1

# %% [markdown]
# # Data Preparation

# %%
#Data Cleaning
myretaildata['Item Type Name'] = myretaildata['Item Type Name'].str.strip()
myretaildata.dropna(axis=0, subset=['Invoice No'], inplace=True)
myretaildata['Invoice No'] = myretaildata['Invoice No'].astype('str')
myretaildata = myretaildata[~myretaildata['Invoice No'].str.contains('C')]
myretaildata.head()
# Out:
#        Invoice No      Invoice Created Shipping Address State  \
# 6   NIMAT25F01096  2025-01-02 09:53:00            Maharashtra
# 13  NIMAT25F01095  2025-01-02 09:53:00                  Delhi
# 22  NIMAT25F01099  2025-01-03 09:44:00                Gujarat
# 31  NIMAT25F01098  2025-01-03 09:44:00              Telangana
# 32  NIMAT25F01100  2025-01-03 09:44:00            Maharashtra
#
#                                        Item Type Name  Item SKU Code     MRP  \
# 6   Floral Embroidered Regular Thread Work Kurta w...    ADWHT006-XS  3499.0
# 13  Floral Embroidered Bell Sleeves Kurta with Tro...     ADBLK034-M  3299.0
# 22  Women Empire Gotta Patti Chanderi Silk Kurta w...   ADKSET165-XL  7999.0
# 31  Embroidered Empire Sequinned Silk Crepe Kurta ...     ADGRY041-S  4499.0
# 32                                 Brocade Co-Ord Set  ADCRDSET159-M  4999.0
#
#     Customer Id  Separator
# 6      20007903          1
# 13     20013731          1
# 22     20031252          1
# 31     20037806          1
# 32     20037808          1

# %%
import pandas as pd

file_name = 'MBA_data.xlsx'

sheet2_data = pd.read_excel(file_name, sheet_name=1)

print(sheet2_data)
# Out:
#                                       States  Orders
# 0                  Andaman & Nicobar Islands       5
# 1                             Andhra Pradesh      79
# 2                          Arunachal Pradesh       8
# 3                                      Assam      83
# 4                                      Bihar     273
# 5                                 Chandigarh      34
# 6                               Chhattisgarh     102
# 7   Dadra and Nagar Haveli and Daman and Diu       1
# 8                                Daman & Diu       2
# 9                                      Delhi     495
# 10                                       Goa      28
# 11                                   Gujarat     310
# 12                                   Haryana     470
# 13                          Himachal Pradesh      28
# 14                           Jammu & Kashmir      42
# 15                                 Jharkhand     126
# 16                                 Karnataka     482
# 17                                    Kerala      53
# 18                            Madhya Pradesh     340
# 19                               Maharashtra     830
# 20                                   Manipur       3
# 21                                 Meghalaya       2
# 22                                   Mizoram       1
# 23                                  Nagaland       3
# 24                                    Odisha     112
# 25                                Puducherry       4
# 26                                    Punjab     139
# 27                                 Rajasthan     281
# 28                                    Sikkim       7
# 29                                Tamil Nadu     108
# 30                                 Telangana     175
# 31                                   Tripura      14
# 32                             Uttar Pradesh     935
# 33                               Uttarakhand      70
# 34                               West Bengal     215

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import requests

data = {
    "States": [
        "Andaman & Nicobar Islands", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh",
        "Dadra and Nagar Haveli and Daman and Diu", "Daman & Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh",
        "Jammu & Kashmir", "Jharkhand", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya",
        "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telangana",
        "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Orders": [
        5, 79, 8, 83, 273, 34, 102, 1, 2, 495, 28, 310, 470, 28, 42, 126, 482, 53, 340, 830, 3, 2, 1, 3, 112, 4, 139, 281, 7,
        108, 175, 14, 935, 70, 215
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Load GeoJSON for India States
geojson_url = "https://raw.githubusercontent.com/geohacker/india/master/state/india_telengana.geojson"
geojson_data = requests.get(geojson_url).json()

# Generate Choropleth Map
fig = px.choropleth(
    df,
    geojson=geojson_data,
    featureidkey="properties.NAME_1",
    locations="States",
    color="Orders",
    title="Order Count by State in India",
    color_continuous_scale="Turbo"
)

# Extract state center coordinates for annotations
state_centers = {
    "Maharashtra": [19.7515, 75.7139],
    "Uttar Pradesh": [26.8467, 80.9462],
    "Haryana": [29.0588, 76.0856],
    "Delhi": [28.7041, 77.1025],
    "Karnataka": [15.3173, 75.7139],
    "Bihar": [25.0961, 85.3131],
    "Madhya Pradesh": [23.4733, 77.9470],
    "West Bengal": [22.9868, 87.8550],
    "Rajasthan": [27.0238, 74.2179],
    "Gujarat": [22.2587, 71.1924],
    "Telangana": [17.1232, 79.2089],
    "Punjab": [31.1471, 75.3412],
    "Tamil Nadu": [11.1271, 78.6569],
    "Odisha": [20.9517, 85.0985],
    "Jharkhand": [23.6102, 85.2799],
    "Chhattisgarh": [21.2787, 81.8661],
    "Assam": [26.2006, 92.9376],
    "Andhra Pradesh": [15.9129, 79.7400],
    "Uttarakhand": [30.0668, 79.0193],
    "Chandigarh": [30.7333, 76.7794],
    "Kerala": [10.8505, 76.2711],
    "Sikkim": [27.5324, 88.5122],
    "Andaman & Nicobar Islands": [11.7401, 92.6586],
    "Jammu & Kashmir": [33.7782, 76.5762],
    "Himachal Pradesh": [31.1048, 77.1734],
    "Arunachal Pradesh": [28.2180, 94.7278],
    "Goa": [15.2993, 74.1240],
    "Tripura": [23.9408, 91.9882],
    "Manipur": [24.6637, 93.9063],
    "Daman & Diu": [20.4283, 72.8397],
    "Nagaland": [26.1584, 94.5624],
    "Meghalaya": [25.4670, 91.3662],
    "Puducherry": [11.9416, 79.8083]
}

# Add labels with small text size
for state, coords in state_centers.items():
    fig.add_trace(go.Scattergeo(
        lon=[coords[1]],
        lat=[coords[0]],
        text=f"<b>{state}</b><br>{df[df['States'] == state]['Orders'].values[0]}",
        mode="text",
        textfont=dict(
            size=8,
            color="black"
        ),
        showlegend=False
    ))

# Update map layout
fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(
    title_font_size=20,
    title_x=0.5,
    margin={"r":0,"t":50,"l":0,"b":0},
    paper_bgcolor="white",
    geo=dict(bgcolor="rgba(0,0,0,0)")
)

# Show the map
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Separating
mybasket = (myretaildata
          .groupby(['Invoice No', 'Item Type Name'])['Separator']
          .sum().unstack().reset_index().fillna(0)
          .set_index('Invoice No'))

# %%
#viewing transaction basket
mybasket.head()
# Out:
# Item Type Name  ADORNIA Self Design Round Neck Sleeveless Embellished Silk Ethnic Jumpsuit  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Bandhani Printed Empire Mirror Work Pure Cotton Kurta with Churidar & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Bandhani Printed Panelled Kurti  Brocade Co-Ord Set  \
# Invoice No
# NIMAT25F00090                               0.0                 0.0
# NIMAT25F00091                               0.0                 0.0
# NIMAT25F00092                               0.0                 0.0
# NIMAT25F00093                               0.0                 0.0
# NIMAT25F00094                               0.0                 0.0
#
# Item Type Name  Embroidered Empire Sequinned Silk Crepe Kurta with Churidar & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 1.0
#
# Item Type Name  Embroidered Notch Neck Sequinned Straight Kurta With Trousers & Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Embroidered Regular Chikankari Kurta with Palazzos  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 1.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Embroidered Regular Sequinned Kurta with Sharara & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Embroidered Regular Sequinned Straight Kurta & Trousers  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Embroidered Round Neck Top With Palazzos  ...  \
# Invoice No                                                ...
# NIMAT25F00090                                        0.0  ...
# NIMAT25F00091                                        0.0  ...
# NIMAT25F00092                                        0.0  ...
# NIMAT25F00093                                        0.0  ...
# NIMAT25F00094                                        0.0  ...
#
# Item Type Name  Women Panelled Gotta Patti Chanderi Silk Kurta with Palazzos & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Women Panelled Gotta Patti Kurta with Palazzos  \
# Invoice No
# NIMAT25F00090                                              0.0
# NIMAT25F00091                                              0.0
# NIMAT25F00092                                              0.0
# NIMAT25F00093                                              0.0
# NIMAT25F00094                                              0.0
#
# Item Type Name  Women Regular Gotta Patti Kurti with Trousers & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Women Regular Kurta with Churidar & With Dupatta  \
# Invoice No
# NIMAT25F00090                                                0.0
# NIMAT25F00091                                                0.0
# NIMAT25F00092                                                0.0
# NIMAT25F00093                                                0.0
# NIMAT25F00094                                                0.0
#
# Item Type Name  Women Regular Kurta with Trousers  \
# Invoice No
# NIMAT25F00090                                 0.0
# NIMAT25F00091                                 0.0
# NIMAT25F00092                                 0.0
# NIMAT25F00093                                 0.0
# NIMAT25F00094                                 0.0
#
# Item Type Name  Woven Design Embroidered Thread Work Anarkali Kurta with Churidar & Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Woven Design Lapel Collar Jacket and Organza Palazzo  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Woven-design 3-Piece Co-Ords  \
# Invoice No
# NIMAT25F00090                            0.0
# NIMAT25F00091                            0.0
# NIMAT25F00092                            0.0
# NIMAT25F00093                            0.0
# NIMAT25F00094                            0.0
#
# Item Type Name  Yoke Design Empire Sequinned Georgette Anarkali Kurta With Churidar & Dupatta  \
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 0.0
# NIMAT25F00094                                                 0.0
#
# Item Type Name  Yoke Design Thread Work V-Neck Anarkali Kurta With Churidar & Dupatta
# Invoice No
# NIMAT25F00090                                                 0.0
# NIMAT25F00091                                                 0.0
# NIMAT25F00092                                                 0.0
# NIMAT25F00093                                                 1.0
# NIMAT25F00094                                                 0.0
#
# [5 rows x 69 columns]

# %%
def my_encode_units(x):
    return 1 if x > 0 else 0  # Simplified condition

my_basket_sets = mybasket.map(my_encode_units)

# %% [markdown]
# # Training Model

# %%
# Ensure the basket dataset is of boolean type
my_basket_sets = my_basket_sets.astype(bool)

# Generating frequent itemsets
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.0005, use_colnames=True)

# %%
#generating rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=0.1)

# %%
#viewing top 10 rules
my_rules.head(100)
# Out:
#                                           antecedents  \
# 0   (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 1                                (Brocade Co-Ord Set)
# 2                                (Brocade Co-Ord Set)
# 3                      (Printed Tunic With Palazzzos)
# 4                                (Brocade Co-Ord Set)
# 5                      (Woven-design 3-Piece Co-Ords)
# 6   (Embroidered Notch Neck Sequinned Straight Kur...
# 7   (Floral Embroidered Regular Thread Work Kurta ...
# 8   (Women Floral Embroidered Regular Kurta with S...
# 9   (Embroidered Notch Neck Sequinned Straight Kur...
# 10                     (Woven-design 3-Piece Co-Ords)
# 11  (Ethnic Motifs Embroidered Straight Scoop Neck...
# 12  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 13  (Ethnic Motifs Printed Gathered Detailed Silk ...
# 14  (Floral Embroidered Gathered Tiered Georgette ...
# 15  (Ethnic Motifs Printed Gathered Detailed Silk ...
# 16                     (Printed Tunic With Palazzzos)
# 17  (Ethnic Motifs Printed Regular Pure Silk Kurta...
# 18  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 19  (Women Regular Kurta with Churidar & With Dupa...
# 20  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 21                     (Woven-design 3-Piece Co-Ords)
# 22  (Women Floral Embroidered Regular Kurta with S...
# 23  (Floral Embroidered Regular Thread Work Kurta ...
# 24                (Women Regular Kurta with Trousers)
# 25  (Floral Embroidered Round Neck Regular A-Line ...
# 26                     (Woven-design 3-Piece Co-Ords)
# 27         (Printed Top & Palazzo With Shrug Co-Ords)
# 28                (Women Regular Kurta with Trousers)
# 29  (V-Neck Regular Georgette Straight Kurta With ...
# 30  (Women Embroidered High Slit Sequinned Silk Ge...
# 31                     (Woven-design 3-Piece Co-Ords)
# 32  (Women Embroidered Regular Sequinned Kurta wit...
# 33  (Women Regular Kurta with Churidar & With Dupa...
# 34                (Women Regular Kurta with Trousers)
# 35    (Women High Slit Pure Silk Kurta with Trousers)
# 36  (Woven Design Lapel Collar Jacket and Organza ...
# 37  (Women Panelled Gotta Patti Chanderi Silk Kurt...
# 38   (Women Panelled Gotta Patti Kurta with Palazzos)
# 39  (Woven Design Embroidered Thread Work Anarkali...
# 40  (Women Regular Kurta with Churidar & With Dupa...
# 41                     (Woven-design 3-Piece Co-Ords)
# 42  (Women Floral Embroidered Regular Kurta with S...
# 43  (Women Floral Embroidered Regular Kurta with S...
# 44  (Embroidered Notch Neck Sequinned Straight Kur...
# 45  (Women Floral Embroidered Regular Kurta with S...
# 46  (Embroidered Notch Neck Sequinned Straight Kur...
# 47  (Floral Embroidered Regular Thread Work Kurta ...
# 48  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 49  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 50  (Women Regular Kurta with Churidar & With Dupa...
# 51  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 52                     (Woven-design 3-Piece Co-Ords)
# 53  (Women Regular Kurta with Churidar & With Dupa...
#
#                                           consequents  antecedent support  \
# 0                                (Brocade Co-Ord Set)            0.028302
# 1   (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.089194
# 2                      (Printed Tunic With Palazzzos)            0.089194
# 3                                (Brocade Co-Ord Set)            0.080617
# 4                      (Woven-design 3-Piece Co-Ords)            0.089194
# 5                                (Brocade Co-Ord Set)            0.018868
# 6   (Floral Embroidered Regular Thread Work Kurta ...            0.006003
# 7   (Embroidered Notch Neck Sequinned Straight Kur...            0.023156
# 8   (Embroidered Notch Neck Sequinned Straight Kur...            0.004288
# 9   (Women Floral Embroidered Regular Kurta with S...            0.006003
# 10  (Ethnic Motifs Embroidered Straight Scoop Neck...            0.018868
# 11                     (Woven-design 3-Piece Co-Ords)            0.016295
# 12  (Ethnic Motifs Printed Gathered Detailed Silk ...            0.028302
# 13  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.008576
# 14  (Ethnic Motifs Printed Gathered Detailed Silk ...            0.016295
# 15  (Floral Embroidered Gathered Tiered Georgette ...            0.008576
# 16  (Ethnic Motifs Printed Regular Pure Silk Kurta...            0.080617
# 17                     (Printed Tunic With Palazzzos)            0.010292
# 18  (Women Regular Kurta with Churidar & With Dupa...            0.028302
# 19  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.023156
# 20                     (Woven-design 3-Piece Co-Ords)            0.028302
# 21  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.018868
# 22  (Floral Embroidered Regular Thread Work Kurta ...            0.004288
# 23  (Women Floral Embroidered Regular Kurta with S...            0.023156
# 24  (Floral Embroidered Round Neck Regular A-Line ...            0.074614
# 25                (Women Regular Kurta with Trousers)            0.001715
# 26         (Printed Top & Palazzo With Shrug Co-Ords)            0.018868
# 27                     (Woven-design 3-Piece Co-Ords)            0.009434
# 28  (V-Neck Regular Georgette Straight Kurta With ...            0.074614
# 29                (Women Regular Kurta with Trousers)            0.006003
# 30                     (Woven-design 3-Piece Co-Ords)            0.011149
# 31  (Women Embroidered High Slit Sequinned Silk Ge...            0.018868
# 32  (Women Regular Kurta with Churidar & With Dupa...            0.002573
# 33  (Women Embroidered Regular Sequinned Kurta wit...            0.023156
# 34    (Women High Slit Pure Silk Kurta with Trousers)            0.074614
# 35                (Women Regular Kurta with Trousers)            0.009434
# 36  (Women Panelled Gotta Patti Chanderi Silk Kurt...            0.012864
# 37  (Woven Design Lapel Collar Jacket and Organza ...            0.006861
# 38  (Woven Design Embroidered Thread Work Anarkali...            0.002573
# 39   (Women Panelled Gotta Patti Kurta with Palazzos)            0.034305
# 40                     (Woven-design 3-Piece Co-Ords)            0.023156
# 41  (Women Regular Kurta with Churidar & With Dupa...            0.018868
# 42  (Floral Embroidered Regular Thread Work Kurta ...            0.000858
# 43  (Embroidered Notch Neck Sequinned Straight Kur...            0.000858
# 44  (Women Floral Embroidered Regular Kurta with S...            0.000858
# 45  (Embroidered Notch Neck Sequinned Straight Kur...            0.004288
# 46  (Women Floral Embroidered Regular Kurta with S...            0.006003
# 47  (Women Floral Embroidered Regular Kurta with S...            0.023156
# 48  (Women Regular Kurta with Churidar & With Dupa...            0.000858
# 49                     (Woven-design 3-Piece Co-Ords)            0.000858
# 50  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.000858
# 51  (Women Regular Kurta with Churidar & With Dupa...            0.028302
# 52  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.018868
# 53  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.023156
#
#     consequent support   support  confidence        lift  representativity  \
# 0             0.089194  0.000858    0.030303    0.339744               1.0
# 1             0.028302  0.000858    0.009615    0.339744               1.0
# 2             0.080617  0.000858    0.009615    0.119272               1.0
# 3             0.089194  0.000858    0.010638    0.119272               1.0
# 4             0.018868  0.000858    0.009615    0.509615               1.0
# 5             0.089194  0.000858    0.045455    0.509615               1.0
# 6             0.023156  0.000858    0.142857    6.169312               1.0
# 7             0.006003  0.000858    0.037037    6.169312               1.0
# 8             0.006003  0.000858    0.200000   33.314286               1.0
# 9             0.004288  0.000858    0.142857   33.314286               1.0
# 10            0.016295  0.000858    0.045455    2.789474               1.0
# 11            0.018868  0.000858    0.052632    2.789474               1.0
# 12            0.008576  0.000858    0.030303    3.533333               1.0
# 53  0.000838    1.037571       1.000000  0.037037   0.036210    0.518519

# %%
#Filtering rules based on condition
my_rules[ (my_rules['lift'] >= 3) &
       (my_rules['confidence'] >= 0.3) ]
# Out:
#                                           antecedents  \
# 25  (Floral Embroidered Round Neck Regular A-Line ...
# 32  (Women Embroidered Regular Sequinned Kurta wit...
# 38   (Women Panelled Gotta Patti Kurta with Palazzos)
# 42  (Women Floral Embroidered Regular Kurta with S...
# 43  (Women Floral Embroidered Regular Kurta with S...
# 44  (Embroidered Notch Neck Sequinned Straight Kur...
# 48  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 49  (Ethnic Motifs Yoke Design Gotta Patti Chander...
# 50  (Women Regular Kurta with Churidar & With Dupa...
#
#                                           consequents  antecedent support  \
# 25                (Women Regular Kurta with Trousers)            0.001715
# 32  (Women Regular Kurta with Churidar & With Dupa...            0.002573
# 38  (Woven Design Embroidered Thread Work Anarkali...            0.002573
# 42  (Floral Embroidered Regular Thread Work Kurta ...            0.000858
# 43  (Embroidered Notch Neck Sequinned Straight Kur...            0.000858
# 44  (Women Floral Embroidered Regular Kurta with S...            0.000858
# 48  (Women Regular Kurta with Churidar & With Dupa...            0.000858
# 49                     (Woven-design 3-Piece Co-Ords)            0.000858
# 50  (Ethnic Motifs Yoke Design Gotta Patti Chander...            0.000858
#
#     consequent support   support  confidence        lift  representativity  \
# 25            0.074614  0.000858    0.500000    6.701149               1.0
# 32            0.023156  0.000858    0.333333   14.395062               1.0
# 38            0.034305  0.000858    0.333333    9.716667               1.0
# 42            0.023156  0.000858    1.000000   43.185185               1.0
# 43            0.006003  0.000858    1.000000  166.571429               1.0
# 44            0.004288  0.000858    1.000000  233.200000               1.0
# 48            0.023156  0.000858    1.000000   43.185185               1.0
# 49            0.018868  0.000858    1.000000   53.000000               1.0
# 50            0.028302  0.000858    1.000000   35.333333               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 25  0.000730    1.850772       0.852234  0.011364   0.459685    0.255747
# 32  0.000798    1.465266       0.932932  0.034483   0.317530    0.185185
# 38  0.000769    1.448542       0.899398  0.023810   0.309651    0.179167
# 42  0.000838         inf       0.977682  0.037037   1.000000    0.518519
# 43  0.000852         inf       0.994850  0.142857   1.000000    0.571429
# 44  0.000854         inf       0.996567  0.200000   1.000000    0.600000
# 48  0.000838         inf       0.977682  0.037037   1.000000    0.518519
# 49  0.000841         inf       0.981974  0.045455   1.000000    0.522727
# 50  0.000833         inf       0.972532  0.030303   1.000000    0.515152

# %% [markdown]
# # Making re-commendations

# %%
# Export the top 100 Market Basket Analysis rules to CSV
my_rules.head(100).to_csv("market_basket_analysis.csv", index=False)

print("Market Basket Analysis rules exported successfully!")
# Out:
# Market Basket Analysis rules exported successfully!

# %%
my_basket_sets['Woven-design 3-Piece Co-Ords'].sum()
# Out:
# np.int64(22)

# %%
my_basket_sets['Brocade Co-Ord Set'].sum()
# Out:
# np.int64(104)
